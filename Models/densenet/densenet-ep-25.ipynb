# %%
import os

# %%
path =  '../input/plant-village-color-lite/Plant_leave_diseases_dataset_with_augmentation/'

# %%
labels =os.listdir(path)

# %%
labels
# Out:
# ['Corn___Northern_Leaf_Blight',
#  'Tomato___Late_blight',
#  'Tomato___healthy',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Background_without_leaves',
#  'Potato___healthy',
#  'Tomato___Early_blight',
#  'Tomato___Septoria_leaf_spot',
#  'Corn___healthy',
#  'Strawberry___Leaf_scorch',
#  'Peach___healthy',
#  'Apple___Apple_scab',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Bacterial_spot',
#  'Apple___Black_rot',
#  'Blueberry___healthy',
#  'Cherry___Powdery_mildew',
#  'Peach___Bacterial_spot',
#  'Apple___Cedar_apple_rust',
#  'Tomato___Target_Spot',
#  'Pepper,_bell___healthy',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Potato___Late_blight',
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Strawberry___healthy',
#  'Corn___Common_rust',
#  'Apple___healthy',
#  'Grape___Black_rot',
#  'Potato___Early_blight',
#  'Grape___Esca_(Black_Measles)',
#  'Raspberry___healthy',
#  'Tomato___Leaf_Mold',
#  'Cherry___healthy',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Pepper,_bell___Bacterial_spot']

# %%
d = {}
for x in labels :
    d[x] = len(os.listdir(path+"//"+x))

# %%
len(d)
# Out:
# 39

# %%
d
# Out:
# {'Corn___Northern_Leaf_Blight': 1000,
#  'Tomato___Late_blight': 1909,
#  'Tomato___healthy': 1591,
#  'Grape___healthy': 1000,
#  'Orange___Haunglongbing_(Citrus_greening)': 5507,
#  'Soybean___healthy': 5090,
#  'Squash___Powdery_mildew': 1835,
#  'Background_without_leaves': 1143,
#  'Potato___healthy': 1000,
#  'Tomato___Early_blight': 1000,
#  'Tomato___Septoria_leaf_spot': 1771,
#  'Corn___healthy': 1162,
#  'Strawberry___Leaf_scorch': 1109,
#  'Peach___healthy': 1000,
#  'Apple___Apple_scab': 1000,
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 5357,
#  'Tomato___Bacterial_spot': 2127,
#  'Apple___Black_rot': 1000,
#  'Blueberry___healthy': 1502,
#  'Cherry___Powdery_mildew': 1052,
#  'Peach___Bacterial_spot': 2297,
#  'Apple___Cedar_apple_rust': 1000,
#  'Tomato___Target_Spot': 1404,
#  'Pepper,_bell___healthy': 1478,
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 1076,
#  'Potato___Late_blight': 1000,
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot': 1000,
#  'Tomato___Tomato_mosaic_virus': 1000,
#  'Strawberry___healthy': 1000,
#  'Corn___Common_rust': 1192,
#  'Apple___healthy': 1645,
#  'Grape___Black_rot': 1180,
#  'Potato___Early_blight': 1000,
#  'Grape___Esca_(Black_Measles)': 1383,
#  'Raspberry___healthy': 1000,
#  'Tomato___Leaf_Mold': 1000,
#  'Cherry___healthy': 1000,
#  'Tomato___Spider_mites Two-spotted_spider_mite': 1676,
#  'Pepper,_bell___Bacterial_spot': 1000}

# %%
import numpy as np
import pandas as pd

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import random
import os

# %%
filenames = os.listdir("../input/plant-village-color-lite/Plant_leave_diseases_dataset_with_augmentation")

# %%
leaf_files = []
leaf_categories = []

# %%
for filename in filenames:
    
    filepath  = "../input/plant-village-color-lite/Plant_leave_diseases_dataset_with_augmentation//" + filename
    
    for x in os.listdir(file):
        p = filepath +"//"+ x
        leaf_files.append(p)
        leaf_categories.append(filename)
#         print(filename,p)
    
df = pd.DataFrame({
    'filename': leaf_files,
    'category': leaf_categories
})

# %%
df.head()
# Out:
#                                             filename  \
# 0  ../input/plant-village-color-lite/Plant_leave_...
# 1  ../input/plant-village-color-lite/Plant_leave_...
# 2  ../input/plant-village-color-lite/Plant_leave_...
# 3  ../input/plant-village-color-lite/Plant_leave_...
# 4  ../input/plant-village-color-lite/Plant_leave_...
#
#                       category
# 0  Corn___Northern_Leaf_Blight
# 1  Corn___Northern_Leaf_Blight
# 2  Corn___Northern_Leaf_Blight
# 3  Corn___Northern_Leaf_Blight
# 4  Corn___Northern_Leaf_Blight

# %%
IMAGE_SIZE = (224,224)

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Model,Sequential, Input
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications import DenseNet121

densenet = DenseNet121(weights='imagenet', include_top=False)

inx = Input(shape=(224, 224, 3))

inz = densenet(inz)
inz = GlobalAveragePooling2D()(inz)
inz = BatchNormalization()(inz)
inz = Dropout(0.5)(inz)
inz = Dense(256, activation='relu')(inz)
inz = BatchNormalization()(inz)
inz = Dropout(0.5)(inz)

    # multi output
output = Dense(39,activation = 'softmax', name='root')(inz)
 
model = Model(inx,output)
    
optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# 2021-09-11 15:00:23.926359: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-11 15:00:23.929656: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-11 15:00:23.977021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:23.977658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-11 15:00:23.977720: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-11 15:00:24.002362: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-11 15:00:24.002457: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-11 15:00:24.020508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-11 15:00:24.048361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-11 15:00:24.074498: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-11 15:00:24.081883: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-11 15:00:24.084870: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-11 15:00:24.085048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:24.085703: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:24.087171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-11 15:00:24.087599: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-11 15:00:24.087814: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-11 15:00:24.088045: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:24.088615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-11 15:00:24.088662: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-11 15:00:24.088701: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-11 15:00:24.088723: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-11 15:00:24.088743: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-11 15:00:24.088763: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-11 15:00:24.088783: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-11 15:00:24.088822: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-11 15:00:24.088845: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-11 15:00:24.088953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:24.089576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:24.090119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-11 15:00:24.091196: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-11 15:00:25.531957: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-11 15:00:25.532003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-11 15:00:25.532014: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-11 15:00:25.534177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:25.534930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:25.535553: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:00:25.536121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 39)                10023
# =================================================================
# Total params: 7,315,047
# Trainable params: 7,228,839
# Non-trainable params: 86,208
# _________________________________________________________________

# %%
redz = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
check_point1 = ModelCheckpoint('model_2.h5', verbose=1, save_best_only=True)

# %%
train_z, validate_Z = train_test_split(df, test_size=0.20, random_state=42)
train_z= train_z.reset_index(drop=True)
validate_z = validate_z.reset_index(drop=True)
train_z.head()
plt.figure(figsize = (20,20))
train_z['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
total_train = train_z.shape[0]
total_validation = validate_z.shape[0]
batch_size = 64

# %%
t_datagenerator = ImageDataGenerator(
    
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    validation_split=0.2,
    height_shift_range=0.1
)

t_generator = t_datagenerator.flow_from_dataframe(
    train_z, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 49188 validated image filenames belonging to 39 classes.

# %%
v_datagenerator = ImageDataGenerator(rescale=1/255)

v_generator = v_datagenerator.flow_from_dataframe(
    validate_z, 
    
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
   
)
# Out:
# Found 12298 validated image filenames belonging to 39 classes.

# %%
t_generator.class_indices
# Out:
# {'Apple___Apple_scab': 0,
#  'Apple___Black_rot': 1,
#  'Apple___Cedar_apple_rust': 2,
#  'Apple___healthy': 3,
#  'Background_without_leaves': 4,
#  'Blueberry___healthy': 5,
#  'Cherry___Powdery_mildew': 6,
#  'Cherry___healthy': 7,
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot': 8,
#  'Corn___Common_rust': 9,
#  'Corn___Northern_Leaf_Blight': 10,
#  'Corn___healthy': 11,
#  'Grape___Black_rot': 12,
#  'Grape___Esca_(Black_Measles)': 13,
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 14,
#  'Grape___healthy': 15,
#  'Orange___Haunglongbing_(Citrus_greening)': 16,
#  'Peach___Bacterial_spot': 17,
#  'Peach___healthy': 18,
#  'Pepper,_bell___Bacterial_spot': 19,
#  'Pepper,_bell___healthy': 20,
#  'Potato___Early_blight': 21,
#  'Potato___Late_blight': 22,
#  'Potato___healthy': 23,
#  'Raspberry___healthy': 24,
#  'Soybean___healthy': 25,
#  'Squash___Powdery_mildew': 26,
#  'Strawberry___Leaf_scorch': 27,
#  'Strawberry___healthy': 28,
#  'Tomato___Bacterial_spot': 29,
#  'Tomato___Early_blight': 30,
#  'Tomato___Late_blight': 31,
#  'Tomato___Leaf_Mold': 32,
#  'Tomato___Septoria_leaf_spot': 33,
#  'Tomato___Spider_mites Two-spotted_spider_mite': 34,
#  'Tomato___Target_Spot': 35,
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 36,
#  'Tomato___Tomato_mosaic_virus': 37,
#  'Tomato___healthy': 38}

# %%
epochs=25


modelhistory = model.fit_generator(
    t_generator, 
    epochs=epochs,
    validation_data=v_generator,
    validation_steps=total_validation//batch_size,
    steps_per_epoch=total_train//batch_size,callbacks=[redz, check_point1])
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021-09-11 15:01:07.280062: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-11 15:01:07.283572: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000165000 Hz
# Epoch 1/25
# 2021-09-11 15:01:17.333177: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-11 15:01:18.185574: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-11 15:01:18.328316: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 768/768 [==============================] - 890s 1s/step - loss: 1.9876 - accuracy: 0.5384 - val_loss: 0.0911 - val_accuracy: 0.9726
#
# Epoch 00001: val_loss improved from inf to 0.09110, saving model to model_2.h5
# Epoch 2/25
# 768/768 [==============================] - 769s 1s/step - loss: 0.1475 - accuracy: 0.9610 - val_loss: 0.0660 - val_accuracy: 0.9787
#
# Epoch 00002: val_loss improved from 0.09110 to 0.06604, saving model to model_2.h5
# Epoch 3/25
# 768/768 [==============================] - 725s 943ms/step - loss: 0.0830 - accuracy: 0.9778 - val_loss: 0.0414 - val_accuracy: 0.9864
#
# Epoch 00003: val_loss improved from 0.06604 to 0.04140, saving model to model_2.h5
# Epoch 4/25
# 768/768 [==============================] - 722s 940ms/step - loss: 0.0516 - accuracy: 0.9861 - val_loss: 0.0239 - val_accuracy: 0.9924
#
# Epoch 00004: val_loss improved from 0.04140 to 0.02387, saving model to model_2.h5
# Epoch 5/25
# 768/768 [==============================] - 755s 983ms/step - loss: 0.0416 - accuracy: 0.9887 - val_loss: 0.0289 - val_accuracy: 0.9907
#
# Epoch 00005: val_loss did not improve from 0.02387
# Epoch 6/25
# 768/768 [==============================] - 747s 973ms/step - loss: 0.0330 - accuracy: 0.9906 - val_loss: 0.0445 - val_accuracy: 0.9863
#
# Epoch 00006: val_loss did not improve from 0.02387
# Epoch 7/25
# 768/768 [==============================] - 724s 942ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 0.0184 - val_accuracy: 0.9940
#
# Epoch 00007: val_loss improved from 0.02387 to 0.01845, saving model to model_2.h5
# Epoch 8/25
# 768/768 [==============================] - 723s 941ms/step - loss: 0.0213 - accuracy: 0.9943 - val_loss: 0.0252 - val_accuracy: 0.9915
#
# Epoch 00008: val_loss did not improve from 0.01845
# Epoch 9/25
# 768/768 [==============================] - 722s 940ms/step - loss: 0.0177 - accuracy: 0.9958 - val_loss: 0.0136 - val_accuracy: 0.9955
#
# Epoch 00009: val_loss improved from 0.01845 to 0.01357, saving model to model_2.h5
# Epoch 10/25
# 768/768 [==============================] - 730s 951ms/step - loss: 0.0174 - accuracy: 0.9954 - val_loss: 0.0221 - val_accuracy: 0.9926
#
# Epoch 00010: val_loss did not improve from 0.01357
# Epoch 11/25
# 768/768 [==============================] - 724s 943ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.0182 - val_accuracy: 0.9937
#
# Epoch 00011: val_loss did not improve from 0.01357
# Epoch 12/25
# 768/768 [==============================] - 751s 978ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0166 - val_accuracy: 0.9943
#
# Epoch 00012: val_loss did not improve from 0.01357
# Epoch 13/25
# 768/768 [==============================] - 793s 1s/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.0149 - val_accuracy: 0.9950
#
# Epoch 00013: val_loss did not improve from 0.01357
# Epoch 14/25
# 768/768 [==============================] - 834s 1s/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.0187 - val_accuracy: 0.9938
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00014: val_loss did not improve from 0.01357
# Epoch 15/25
# 768/768 [==============================] - 864s 1s/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.0100 - val_accuracy: 0.9963
#
# Epoch 00015: val_loss improved from 0.01357 to 0.00997, saving model to model_2.h5
# Epoch 16/25
# 768/768 [==============================] - 832s 1s/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0078 - val_accuracy: 0.9974
#
# Epoch 00016: val_loss improved from 0.00997 to 0.00783, saving model to model_2.h5
# Epoch 17/25
# 768/768 [==============================] - 806s 1s/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.0113 - val_accuracy: 0.9962
#
# Epoch 00017: val_loss did not improve from 0.00783
# Epoch 18/25
# 768/768 [==============================] - 803s 1s/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 0.0116 - val_accuracy: 0.9966
#
# Epoch 00018: val_loss did not improve from 0.00783
# Epoch 19/25
# 768/768 [==============================] - 854s 1s/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0153 - val_accuracy: 0.9954
#
# Epoch 00019: val_loss did not improve from 0.00783
# Epoch 20/25
# 768/768 [==============================] - 875s 1s/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0093 - val_accuracy: 0.9967
#
# Epoch 00020: val_loss did not improve from 0.00783
# Epoch 21/25
# 768/768 [==============================] - 805s 1s/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0079 - val_accuracy: 0.9974
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00021: val_loss did not improve from 0.00783
# Epoch 22/25
# 768/768 [==============================] - 855s 1s/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0077 - val_accuracy: 0.9972
#
# Epoch 00022: val_loss improved from 0.00783 to 0.00767, saving model to model_2.h5
# Epoch 23/25
# 768/768 [==============================] - 864s 1s/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0092 - val_accuracy: 0.9972
#
# Epoch 00023: val_loss did not improve from 0.00767
# Epoch 24/25
# 768/768 [==============================] - 857s 1s/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0082 - val_accuracy: 0.9974
#
# Epoch 00024: val_loss did not improve from 0.00767
# Epoch 25/25
# 768/768 [==============================] - 846s 1s/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0095 - val_accuracy: 0.9975
#
# Epoch 00025: val_loss did not improve from 0.00767

# %%
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# loss plot
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save_weights("plant(w).h5")
model.save("plant(m).h5")

# %%
d = t_generator.class_indices

import cv2
from tqdm import tqdm
from skimage.transform import resize
pred = []
y_true = []
for f in tqdm(range(len(validate_z))) :
#     print(validate["filename"][f])
    x = cv2.imread(validate_z["filename"][f], cv2.IMREAD_COLOR)
    
        
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
#     print(type(x))
#     print(x.shape)
    x = resize(x, IMAGE_SIZE)
#     print(x.shape)
#     print(x)

    x = x.astype(np.float32)
#     print("aaa",x)
#     print(x.shape)
    x = x.reshape((1,224,224,3))

    pred.append(np.argmax(model.predict([x])[0]))
#     print(d[validate["category"][f]])
    y_true.append(d[validate_z["category"][f]])
    

labels = list(t_generator.class_indices.keys())
# Out:
# 100%|██████████| 12298/12298 [31:19<00:00,  6.54it/s]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(y_true, pred)
plt.figure(figsize=(20,20))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=labels, yticklabels=labels)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 255.29374999999993, 'Predicted')
