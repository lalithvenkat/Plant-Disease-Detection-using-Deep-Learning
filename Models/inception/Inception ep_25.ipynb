# %%
import os

# %%
path =  '../input/colorleaves/Plant_leave_diseases_dataset_with_augmentation/'

# %%
labels =os.listdir(path)

# %%
labels
# Out:
# ['Corn___Northern_Leaf_Blight',
#  'Tomato___Late_blight',
#  'Tomato___healthy',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Background_without_leaves',
#  'Potato___healthy',
#  'Tomato___Early_blight',
#  'Tomato___Septoria_leaf_spot',
#  'Corn___healthy',
#  'Strawberry___Leaf_scorch',
#  'Peach___healthy',
#  'Apple___Apple_scab',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Bacterial_spot',
#  'Apple___Black_rot',
#  'Blueberry___healthy',
#  'Cherry___Powdery_mildew',
#  'Peach___Bacterial_spot',
#  'Apple___Cedar_apple_rust',
#  'Tomato___Target_Spot',
#  'Pepper,_bell___healthy',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Potato___Late_blight',
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot',
#  'Tomato___Tomato_mosaic_virus',
#  'Strawberry___healthy',
#  'Corn___Common_rust',
#  'Apple___healthy',
#  'Grape___Black_rot',
#  'Potato___Early_blight',
#  'Grape___Esca_(Black_Measles)',
#  'Raspberry___healthy',
#  'Tomato___Leaf_Mold',
#  'Cherry___healthy',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Pepper,_bell___Bacterial_spot']

# %%
d = {}
for x in labels :
    d[x] = len(os.listdir(path+x))

# %%
len(d)
# Out:
# 39

# %%
d
# Out:
# {'Corn___Northern_Leaf_Blight': 1000,
#  'Tomato___Late_blight': 1909,
#  'Tomato___healthy': 1591,
#  'Grape___healthy': 1000,
#  'Orange___Haunglongbing_(Citrus_greening)': 5507,
#  'Soybean___healthy': 5090,
#  'Squash___Powdery_mildew': 1835,
#  'Background_without_leaves': 1143,
#  'Potato___healthy': 1000,
#  'Tomato___Early_blight': 1000,
#  'Tomato___Septoria_leaf_spot': 1771,
#  'Corn___healthy': 1162,
#  'Strawberry___Leaf_scorch': 1109,
#  'Peach___healthy': 1000,
#  'Apple___Apple_scab': 1000,
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 5357,
#  'Tomato___Bacterial_spot': 2127,
#  'Apple___Black_rot': 1000,
#  'Blueberry___healthy': 1502,
#  'Cherry___Powdery_mildew': 1052,
#  'Peach___Bacterial_spot': 2297,
#  'Apple___Cedar_apple_rust': 1000,
#  'Tomato___Target_Spot': 1404,
#  'Pepper,_bell___healthy': 1478,
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 1076,
#  'Potato___Late_blight': 1000,
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot': 1000,
#  'Tomato___Tomato_mosaic_virus': 1000,
#  'Strawberry___healthy': 1000,
#  'Corn___Common_rust': 1192,
#  'Apple___healthy': 1645,
#  'Grape___Black_rot': 1180,
#  'Potato___Early_blight': 1000,
#  'Grape___Esca_(Black_Measles)': 1383,
#  'Raspberry___healthy': 1000,
#  'Tomato___Leaf_Mold': 1000,
#  'Cherry___healthy': 1000,
#  'Tomato___Spider_mites Two-spotted_spider_mite': 1676,
#  'Pepper,_bell___Bacterial_spot': 1000}

# %%
import numpy as np
import pandas as pd

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
import random
import os
import matplotlib.pyplot as plt
# Out:
# 2021-09-11 15:06:41.561553: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
filenames = os.listdir("../input/colorleaves/Plant_leave_diseases_dataset_with_augmentation/")

# %%
leaf_files = []
leaf_categories = []

# %%
for filename in filenames:
    
    filepath  = "../input/colorleaves/Plant_leave_diseases_dataset_with_augmentation/" + filename
    
    for x in os.listdir(file):
        p = filepath +"/"+ x
        leaf_files.append(p)
        leaf_categories.append(filename)
#         print(filename,p)
    
df = pd.DataFrame({
    'filename': leaf_files,
    'category': leaf_categories
})

# %%
df.head()
# Out:
#                                             filename  \
# 0  ../input/colorleaves/Plant_leave_diseases_data...
# 1  ../input/colorleaves/Plant_leave_diseases_data...
# 2  ../input/colorleaves/Plant_leave_diseases_data...
# 3  ../input/colorleaves/Plant_leave_diseases_data...
# 4  ../input/colorleaves/Plant_leave_diseases_data...
#
#                       category
# 0  Corn___Northern_Leaf_Blight
# 1  Corn___Northern_Leaf_Blight
# 2  Corn___Northern_Leaf_Blight
# 3  Corn___Northern_Leaf_Blight
# 4  Corn___Northern_Leaf_Blight

# %%
IMAGE_SIZE = (299,299)

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Model,Sequential, Input
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import InceptionV3

inception = InceptionV3(weights='imagenet', include_top=False)
# Out:
# 2021-09-11 15:06:47.004697: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-11 15:06:47.008102: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-11 15:06:47.058445: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:47.059466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-11 15:06:47.059537: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-11 15:06:47.094905: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-11 15:06:47.094992: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-11 15:06:47.123756: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-11 15:06:47.220755: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-11 15:06:47.250065: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-11 15:06:47.258451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-11 15:06:47.261729: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-11 15:06:47.261962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:47.263055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:47.264946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-11 15:06:47.265588: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-11 15:06:47.265859: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-11 15:06:47.266043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:47.266989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-11 15:06:47.267043: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-11 15:06:47.267091: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-11 15:06:47.267153: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-11 15:06:47.267199: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-11 15:06:47.267243: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-11 15:06:47.267306: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-11 15:06:47.267360: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-11 15:06:47.267422: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-11 15:06:47.267565: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:47.268574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:47.269479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-11 15:06:47.270372: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-11 15:06:49.046662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-11 15:06:49.046715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-11 15:06:49.046727: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-11 15:06:49.049529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:49.050592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:49.051636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-11 15:06:49.052569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
for xyz in inception.layers :
    xyz.trainable = False

# %%
inx = Input(shape=(299,299, 3))

lyz = inception(inx)
lyz = GlobalAveragePooling2D()(lyz)
lyz = BatchNormalization()(lyz)
lyz = Dense(1024, activation='relu')(lyz)
lyz = Dropout(0.5)(lyz)
lyz = Dense(512, activation='relu')(lyz)
lyz = Dropout(0.5)(lyz)
lyz = Dense(256, activation='relu')(lyz)
lyz = BatchNormalization()(lyz)
lyz = Dense(128, activation='relu')(lyz)
lyz = Dropout(0.5)(lyz)

    # multi output
output = Dense(39,activation = 'softmax', name='root')(lyz)
 
model = Model(inx,output)
    
optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, None, None, 2048)  21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# root (Dense)                 (None, 39)                5031
# =================================================================
# Total params: 24,604,231
# Trainable params: 2,796,839
# Non-trainable params: 21,807,392
# _________________________________________________________________

# %%
redz = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
check_point1 = ModelCheckpoint('model_2.h5', verbose=1, save_best_only=True)

# %%
train_z, validate_z = train_test_split(df, test_size=0.20, random_state=42)
train_z= train_z.reset_index(drop=True)
validate_z = validate_z.reset_index(drop=True)
train_z.head()
plt.figure(figsize = (20,20))
train_z['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
total_train = train_z.shape[0]
total_validation = validate_z.shape[0]
batch_size = 64

# %%
t_datagenerator = ImageDataGenerator(
    
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    validation_split=0.2,
    height_shift_range=0.1
)

t_generator = t_datagenerator.flow_from_dataframe(
    train_z, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 49188 validated image filenames belonging to 39 classes.

# %%
v_datagenerator = ImageDataGenerator(rescale=1/255)

v_generator = v_datagenerator.flow_from_dataframe(
    validate_z, 
    
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
   
)
# Out:
# Found 12298 validated image filenames belonging to 39 classes.

# %%
t_generator.class_indices
# Out:
# {'Apple___Apple_scab': 0,
#  'Apple___Black_rot': 1,
#  'Apple___Cedar_apple_rust': 2,
#  'Apple___healthy': 3,
#  'Background_without_leaves': 4,
#  'Blueberry___healthy': 5,
#  'Cherry___Powdery_mildew': 6,
#  'Cherry___healthy': 7,
#  'Corn___Cercospora_leaf_spot Gray_leaf_spot': 8,
#  'Corn___Common_rust': 9,
#  'Corn___Northern_Leaf_Blight': 10,
#  'Corn___healthy': 11,
#  'Grape___Black_rot': 12,
#  'Grape___Esca_(Black_Measles)': 13,
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 14,
#  'Grape___healthy': 15,
#  'Orange___Haunglongbing_(Citrus_greening)': 16,
#  'Peach___Bacterial_spot': 17,
#  'Peach___healthy': 18,
#  'Pepper,_bell___Bacterial_spot': 19,
#  'Pepper,_bell___healthy': 20,
#  'Potato___Early_blight': 21,
#  'Potato___Late_blight': 22,
#  'Potato___healthy': 23,
#  'Raspberry___healthy': 24,
#  'Soybean___healthy': 25,
#  'Squash___Powdery_mildew': 26,
#  'Strawberry___Leaf_scorch': 27,
#  'Strawberry___healthy': 28,
#  'Tomato___Bacterial_spot': 29,
#  'Tomato___Early_blight': 30,
#  'Tomato___Late_blight': 31,
#  'Tomato___Leaf_Mold': 32,
#  'Tomato___Septoria_leaf_spot': 33,
#  'Tomato___Spider_mites Two-spotted_spider_mite': 34,
#  'Tomato___Target_Spot': 35,
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 36,
#  'Tomato___Tomato_mosaic_virus': 37,
#  'Tomato___healthy': 38}

# %%
epochs=25


modelhistory = model.fit_generator(
    t_generator, 
    epochs=epochs,
    validation_data=v_generator,
    validation_steps=total_validation//batch_size,
    steps_per_epoch=total_train//batch_size,callbacks=[redz, check_point1])
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021-09-11 15:07:38.240915: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-11 15:07:38.245928: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/25
# 2021-09-11 15:07:43.748523: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-11 15:07:44.716398: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-11 15:07:45.419698: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 768/768 [==============================] - 1388s 2s/step - loss: 3.6570 - accuracy: 0.1507 - val_loss: 1.2636 - val_accuracy: 0.6500
#
# Epoch 00001: val_loss improved from inf to 1.26358, saving model to model_2.h5
# Epoch 2/25
# 768/768 [==============================] - 1199s 2s/step - loss: 1.6744 - accuracy: 0.5201 - val_loss: 0.6147 - val_accuracy: 0.8145
#
# Epoch 00002: val_loss improved from 1.26358 to 0.61470, saving model to model_2.h5
# Epoch 3/25
# 768/768 [==============================] - 1198s 2s/step - loss: 1.0470 - accuracy: 0.6795 - val_loss: 0.4188 - val_accuracy: 0.8718
#
# Epoch 00003: val_loss improved from 0.61470 to 0.41881, saving model to model_2.h5
# Epoch 4/25
# 768/768 [==============================] - 1229s 2s/step - loss: 0.7773 - accuracy: 0.7567 - val_loss: 0.3364 - val_accuracy: 0.8905
#
# Epoch 00004: val_loss improved from 0.41881 to 0.33637, saving model to model_2.h5
# Epoch 5/25
# 768/768 [==============================] - 1211s 2s/step - loss: 0.6629 - accuracy: 0.7970 - val_loss: 0.2906 - val_accuracy: 0.9042
#
# Epoch 00005: val_loss improved from 0.33637 to 0.29063, saving model to model_2.h5
# Epoch 6/25
# 768/768 [==============================] - 1211s 2s/step - loss: 0.5626 - accuracy: 0.8230 - val_loss: 0.2588 - val_accuracy: 0.9136
#
# Epoch 00006: val_loss improved from 0.29063 to 0.25880, saving model to model_2.h5
# Epoch 7/25
# 768/768 [==============================] - 1178s 2s/step - loss: 0.5106 - accuracy: 0.8409 - val_loss: 0.2466 - val_accuracy: 0.9184
#
# Epoch 00007: val_loss improved from 0.25880 to 0.24656, saving model to model_2.h5
# Epoch 8/25
# 768/768 [==============================] - 1199s 2s/step - loss: 0.4689 - accuracy: 0.8544 - val_loss: 0.2258 - val_accuracy: 0.9227
#
# Epoch 00008: val_loss improved from 0.24656 to 0.22581, saving model to model_2.h5
# Epoch 9/25
# 768/768 [==============================] - 1224s 2s/step - loss: 0.4318 - accuracy: 0.8679 - val_loss: 0.2030 - val_accuracy: 0.9308
#
# Epoch 00009: val_loss improved from 0.22581 to 0.20303, saving model to model_2.h5
# Epoch 10/25
# 768/768 [==============================] - 1227s 2s/step - loss: 0.4073 - accuracy: 0.8728 - val_loss: 0.1958 - val_accuracy: 0.9329
#
# Epoch 00010: val_loss improved from 0.20303 to 0.19582, saving model to model_2.h5
# Epoch 11/25
# 768/768 [==============================] - 1215s 2s/step - loss: 0.3726 - accuracy: 0.8853 - val_loss: 0.1894 - val_accuracy: 0.9370
#
# Epoch 00011: val_loss improved from 0.19582 to 0.18942, saving model to model_2.h5
# Epoch 12/25
# 768/768 [==============================] - 1200s 2s/step - loss: 0.3638 - accuracy: 0.8845 - val_loss: 0.1819 - val_accuracy: 0.9386
#
# Epoch 00012: val_loss improved from 0.18942 to 0.18187, saving model to model_2.h5
# Epoch 13/25
# 768/768 [==============================] - 1221s 2s/step - loss: 0.3476 - accuracy: 0.8929 - val_loss: 0.1734 - val_accuracy: 0.9417
#
# Epoch 00013: val_loss improved from 0.18187 to 0.17344, saving model to model_2.h5
# Epoch 14/25
# 768/768 [==============================] - 1186s 2s/step - loss: 0.3407 - accuracy: 0.8946 - val_loss: 0.1657 - val_accuracy: 0.9456
#
# Epoch 00014: val_loss improved from 0.17344 to 0.16566, saving model to model_2.h5
# Epoch 15/25
# 768/768 [==============================] - 1181s 2s/step - loss: 0.3187 - accuracy: 0.9006 - val_loss: 0.1670 - val_accuracy: 0.9434
#
# Epoch 00015: val_loss did not improve from 0.16566
# Epoch 16/25
# 768/768 [==============================] - 1191s 2s/step - loss: 0.3027 - accuracy: 0.9053 - val_loss: 0.1607 - val_accuracy: 0.9456
#
# Epoch 00016: val_loss improved from 0.16566 to 0.16067, saving model to model_2.h5
# Epoch 17/25
# 768/768 [==============================] - 1053s 1s/step - loss: 0.2931 - accuracy: 0.9084 - val_loss: 0.1575 - val_accuracy: 0.9460
#
# Epoch 00017: val_loss improved from 0.16067 to 0.15747, saving model to model_2.h5
# Epoch 18/25
# 768/768 [==============================] - 978s 1s/step - loss: 0.2942 - accuracy: 0.9110 - val_loss: 0.1512 - val_accuracy: 0.9488
#
# Epoch 00018: val_loss improved from 0.15747 to 0.15123, saving model to model_2.h5
# Epoch 19/25
# 768/768 [==============================] - 974s 1s/step - loss: 0.2828 - accuracy: 0.9127 - val_loss: 0.1486 - val_accuracy: 0.9506
#
# Epoch 00019: val_loss improved from 0.15123 to 0.14861, saving model to model_2.h5
# Epoch 20/25
# 768/768 [==============================] - 978s 1s/step - loss: 0.2746 - accuracy: 0.9158 - val_loss: 0.1469 - val_accuracy: 0.9508
#
# Epoch 00020: val_loss improved from 0.14861 to 0.14692, saving model to model_2.h5
# Epoch 21/25
# 768/768 [==============================] - 961s 1s/step - loss: 0.2682 - accuracy: 0.9193 - val_loss: 0.1428 - val_accuracy: 0.9508
#
# Epoch 00021: val_loss improved from 0.14692 to 0.14278, saving model to model_2.h5
# Epoch 22/25
# 768/768 [==============================] - 967s 1s/step - loss: 0.2586 - accuracy: 0.9190 - val_loss: 0.1389 - val_accuracy: 0.9543
#
# Epoch 00022: val_loss improved from 0.14278 to 0.13886, saving model to model_2.h5
# Epoch 23/25
# 768/768 [==============================] - 971s 1s/step - loss: 0.2502 - accuracy: 0.9223 - val_loss: 0.1427 - val_accuracy: 0.9529
#
# Epoch 00023: val_loss did not improve from 0.13886
# Epoch 24/25
# 768/768 [==============================] - 977s 1s/step - loss: 0.2347 - accuracy: 0.9264 - val_loss: 0.1365 - val_accuracy: 0.9529
#
# Epoch 00024: val_loss improved from 0.13886 to 0.13653, saving model to model_2.h5
# Epoch 25/25
# 768/768 [==============================] - 982s 1s/step - loss: 0.2435 - accuracy: 0.9230 - val_loss: 0.1342 - val_accuracy: 0.9560
#
# Epoch 00025: val_loss improved from 0.13653 to 0.13417, saving model to model_2.h5

# %%
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# loss plot
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save_weights("plant(w).h5")
model.save("plant(m).h5")

# %%
d = t_generator.class_indices

import cv2
from tqdm import tqdm
from skimage.transform import resize
pred = []
y_true = []
for f in tqdm(range(len(validate_z))) :
#     print(validate["filename"][f])
    x = cv2.imread(validate_z["filename"][f], cv2.IMREAD_COLOR)
    
        
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
#     print(type(x))
#     print(x.shape)
    x = resize(x, IMAGE_SIZE)
#     print(x.shape)
#     print(x)

    x = x.astype(np.float32)
#     print("aaa",x)
#     print(x.shape)
    x = x.reshape((1,299,299,3))

    pred.append(np.argmax(model.predict([x])[0]))
#     print(d[validate["category"][f]])
    y_true.append(d[validate_z["category"][f]])
    

labels = list(t_generator.class_indices.keys())
# Out:
# 100%|██████████| 12298/12298 [23:51<00:00,  8.59it/s]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(y_true, pred)
plt.figure(figsize=(20,20))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=labels, yticklabels=labels)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 255.29374999999993, 'Predicted')
